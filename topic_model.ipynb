# %% [markdown]
# <a href="https://colab.research.google.com/github/13lop/topic-model-arxiv/blob/main/topic_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Some of the dependencies we use don't need to be installed when the notebook is run on Colab, because they are included in every Colab environment.
# Overview of dependencies:
# *   **`bertopic`**: The core package for BERTopic-based topic modeling.
# *   **`litellm`**: A package that simplifies LLM API calls by providing a single API client for any LLM provider (e.g. Gemini, Anthropic, OpenAI, AWS Bedrock, etc.)
# *   **`octis`**: Used for topic coherence and topic diversity evaluation metrics.
# *   **`sentence-transformers`**: Used for generating sentence embeddings, which are crucial for BERTopic's understanding of semantic meaning.
# *   **`scikit-learn`**: Provides machine learning tools, including CountVectorizer used here for text preprocessing.
# *   **`pandas`**: Used for data manipulation, data analysis, and working with DataFrames.
# *   **`torch`**: PyTorch is a deep learning framework, and we are using it to check for GPU hardware acceleration availability.
# *   **`kagglehub`**: Used to fetch data from Kaggle.

# %%
# Suppresses output; remove if you want to see the output
# %%capture
# !pip uninstall -y scikit-learn || true

# OCTIS is set up to require scikit-learn 1.1.0, which causes unnecessary conflicts
# Install OCTIS, but ignore its outdated requirements.txt
# !pip install --no-deps octis==1.14.0

# !pip install scikit-learn==1.4.2
# !pip install gensim==4.3.3

# !pip install numpy scipy pandas nltk spacy \
            sentence_transformers scikit-optimize matplotlib \
            torch tomotopy flask requests libsvm

# %%
# Suppresses output; remove if you want to see the output
# %%capture
# !pip install bertopic==0.17.0 kagglehub==0.3.5 litellm==1.69.2 --quiet

# %%
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
import torch
import kagglehub
import numpy as np
import os

# Construct the correct path to the CSV file in the Kaggle input directory
path = kagglehub.dataset_download('student344/arxiv-ml-ai-052023-052025',
                                  path="arxiv_ml_ai_papers_last_2_years.csv")
# Load the dataset into a pandas DataFrame directly from the input path
df = pd.read_csv(path)

df["text"] = df["title"] + " " + df["summary"]
print("The dataset has been parsed successfully.")
# Out:
# The dataset has been parsed successfully.

# %% [markdown]
# After importing the required libraries, we combine each paper's title and abstract into a single text column for preprocessing. This combined text serves as input for our embedding model.
#
# We preserve most of the text, including stop words, since transformer-based embedding models require full contextual information to generate accurate embeddings. Light preprocessing is performed to remove escape characters, LaTeX code, URLs, and other noise. [As recommended by BERTopic's developers](https://maartengr.github.io/BERTopic/faq.html#how-do-i-remove-stop-words), any additional preprocessing steps are performed *after* generating the embeddings.

# %%
import re

def preprocess(text: str) -> str:
    # Remove inline LaTeX math expressions: $...$
    text = re.sub(r'\$(.*?)\$', '', text)

    # Remove display math
    text = re.sub(r'\$\$(.*?)\$\$', '', text, flags=re.DOTALL)
    text = re.sub(r'\\(.*?)(.*?)\\', '', text, flags=re.DOTALL)

    # Remove common LaTeX commands (e.g., "\cite{}", "?????????\ref{}", etc.)
    text = re.sub(r'\\[a-zA-Z]+\{.*?\}', '', text)
    # Remove LaTeX escape sequences such as \\% or \\_
    text = re.sub(r'\\([%_&#$])', r'\1', text)

    # Remove multiple spaces and newlines
    text = re.sub(r'\s+', ' ', text)

    # Remove URLs (http/https)
    text = re.sub(r'http\S+|www\.\S+', '', text)

    # Strip leading/trailing whitespace
    text = text.strip()

    return text

docs = df['text'].apply(preprocess).to_list()
print('Data preprocessing complete.')
# Out:
# Data preprocessing complete.

# %% [markdown]
# ## 3. Creating the Text Embeddings

# %% [markdown]
# Sentence embeddings are numerical representations of text that capture semantic meaning. We use a pretrained SentenceTransformers model to generate the embeddings of our data.
#
# *   **Embedding Model:** We use the "avsolatorio/GIST-small-Embedding-v0" model (via SentenceTransformers), one of the highest scoring semantic text embedding models of the <100m parameter range on the [MTEB leaderboard](https://huggingface.co/spaces/mteb/leaderboard), particularly on clustering-related benchmarks. This model has a 33.4 million parameter size, which is lightweight enough to load quickly in a Colab runtime (with the GPU runtime enabled).
# *   **Encoding:** The `embedding_model.encode()` function generates embeddings for the `docs` (the list of paper texts).
# *   **Device Usage:** `device=device` ensures that the embedding generation uses the available hardware acceleration (GPU or CPU).

# %%
device = 'cuda' if torch.cuda.is_available() else 'mps' if torch.backends.mps.is_available() else 'cpu'
embedding_model_name = "avsolatorio/GIST-small-Embedding-v0"

embedding_model = SentenceTransformer(embedding_model_name,
                                      trust_remote_code=True,
                                      device=device,
                                     )
print("Creating embeddings...")
embeddings = embedding_model.encode(docs, show_progress_bar=True)
# Out:
# Creating embeddings...
# Batches:   0%|          | 0/379 [00:00<?, ?it/s]

# %% [markdown]
# ## 4. Creating the Topic Model

# %% [markdown]
# We are now ready to initialize a BERTopic model.
#
# #### Parameters
# - Now that the embeddings are generated, CountVectorizer is used to remove English stop words (words like "for", "and", " "to", etc.).
# - The previously defined embedding model is used.
# - N-gram range of (1,3) is used to capture single words, bi-grams (pairs of words such as "Computer Vision" and "Reinforcement Learning"), and tri-grams (terms like "Large Language Models" "Time Series Forecasting", etc.)
# - Verbose mode enabled for training progress updates.
# - We set a minimum topic size of 35, so that smaller topics with less than 35 document examples do not get clustered. This prevents noise in the results at the expense of not capturing the entire breadth of topics in the dataset.

# %%
vectorizer_model = CountVectorizer(stop_words="english", ngram_range=(1, 2))
print("Creating new model...")

topic_model = BERTopic(
    verbose=True,
    embedding_model=embedding_model,
    vectorizer_model=vectorizer_model,
    n_gram_range=(1, 3),
    min_topic_size=30,
)

topics, probs = topic_model.fit_transform(docs, embeddings)
print("The topic model has been created.")
# Out:
# 2025-06-30 08:44:19,622 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# Creating new model...
# 2025-06-30 08:44:52,720 - BERTopic - Dimensionality - Completed ✓
# 2025-06-30 08:44:52,722 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2025-06-30 08:44:53,248 - BERTopic - Cluster - Completed ✓
# 2025-06-30 08:44:53,255 - BERTopic - Representation - Fine-tuning topics using representation models.
# 2025-06-30 08:45:00,263 - BERTopic - Representation - Completed ✓
# The topic model has been created.

# %% [markdown]
# The following table shows the model output. We will explore this further in the sections below.
# - **Topic**: The topic ID. Note that the Topic ID "-1" represents the outliers (documents that were not clustered into any specific topic).
# - **Count**: The number of documents that were clustered into the topic.
# - **Representation**: The list of the top words that represent the topic.
# - **Representative_Docs**: A sample of representative documents for the topic.

# %%
topic_info = topic_model.get_topic_info()
topic_info.head(30)
# Out:
#     Topic  Count                                               Name  \
# 0      -1   3721                      -1_models_data_model_learning
# 1       0    774                    0_learning_neural_networks_data
# 2       1    342             1_language_llms_models_language models
# 3       2    319          2_federated_fl_federated learning_clients
# 4       3    314   3_reinforcement_reinforcement learning_rl_policy
# 5       4    294            4_traffic_driving_autonomous_trajectory
# 6       5    253                    5_segmentation_images_mri_image
# 7       6    244                 6_ai_human_intelligence_ai systems
# 8       7    242                   7_visual_multimodal_image_vision
# 9       8    226               8_robot_manipulation_robots_learning
# 10      9    219                           9_graph_node_graphs_gnns
# 11     10    216              10_code_software_llms_code generation
# 12     11    183             11_series_time series_time_forecasting
# 13     12    164                12_reasoning_llms_mathematical_math
# 14     13    151         13_adversarial_attacks_robustness_backdoor
# 15     14    151            14_recommendation_user_recommender_item
# 16     15    144                        15_speech_audio_speaker_asr
# 17     16    141                    16_regret_bandit_online_bandits
# 18     17    141        17_bayesian_uncertainty_inference_posterior
# 19     18    139     18_diffusion_diffusion models_models_denoising
# 20     19    138      19_quantum_classical_quantum machine_learning
# 21     20    137                      20_attacks_llms_attack_safety
# 22     21    135     21_causal_treatment_variables_causal discovery
# 23     22    134                       22_neural_pdes_equations_pde
# 24     23    130                          23_eeg_brain_fmri_signals
# 25     24    130                       24_agents_agent_language_llm
# 26     25    129  25_object_segmentation_object detection_detection
# 27     26    121                   26_channel_network_wireless_edge
# 28     27    120                   27_crop_detection_images_species
# 29     28    117                28_retrieval_rag_question_knowledge
#
#                                        Representation  \
# 0   [models, data, model, learning, based, languag...
# 1   [learning, neural, networks, data, gradient, o...
# 2   [language, llms, models, language models, larg...
# 3   [federated, fl, federated learning, clients, p...
# 4   [reinforcement, reinforcement learning, rl, po...
# 5   [traffic, driving, autonomous, trajectory, veh...
# 6   [segmentation, images, mri, image, medical, ca...
# 7   [ai, human, intelligence, ai systems, systems,...
# 8   [visual, multimodal, image, vision, language, ...
# 9   [robot, manipulation, robots, learning, roboti...
# 10  [graph, node, graphs, gnns, graph neural, node...
# 11  [code, software, llms, code generation, genera...
# 12  [series, time series, time, forecasting, serie...
# 13  [reasoning, llms, mathematical, math, language...
# 14  [adversarial, attacks, robustness, backdoor, a...
# 15  [recommendation, user, recommender, item, reco...
# 16  [speech, audio, speaker, asr, separation, voic...
# 17  [regret, bandit, online, bandits, algorithm, a...
# 18  [bayesian, uncertainty, inference, posterior, ...
# 19  [diffusion, diffusion models, models, denoisin...
# 20  [quantum, classical, quantum machine, learning...
# 21  [attacks, llms, attack, safety, llm, jailbreak...
# 22  [causal, treatment, variables, causal discover...
# 23  [neural, pdes, equations, pde, differential eq...
# 24  [eeg, brain, fmri, signals, classification, sl...
# 25  [agents, agent, language, llm, llms, game, tas...
# 26  [object, segmentation, object detection, detec...
# 27  [channel, network, wireless, edge, communicati...
# 28  [crop, detection, images, species, imagery, da...
# 29  [retrieval, rag, question, knowledge, answerin...
#
#                                   Representative_Docs
# 0   [Unleashing the Power of Pre-trained Language ...
# 1   [A Nearly Optimal Single Loop Algorithm for St...
# 2   [How Multilingual Are Large Language Models Fi...
# 3   [Adaptive Self-Distillation for Minimizing Cli...
# 4   [Sharper Model-free Reinforcement Learning for...
# 5   [Risk-anticipatory autonomous driving strategi...
# 6   [Cross-dimensional transfer learning in medica...
# 7   [Human-AI collaboration is not very collaborat...
# 8   [MLLMs-Augmented Visual-Language Representatio...
# 9   [VITAL: Visual Teleoperation to Enhance Robot ...
# 10  [Graph Rewriting for Graph Neural Networks Giv...
# 11  [SEED: Customize Large Language Models with Sa...
# 12  [Times2D: Multi-Period Decomposition and Deriv...
# 13  [Phi-4-reasoning Technical Report We introduce...
# 14  [Benchmarking and Analyzing Robust Point Cloud...
# 15  [A Survey on Large Language Models for Recomme...
# 16  [RepCodec: A Speech Representation Codec for S...
# 17  [Best Arm Identification with Minimal Regret M...
# 18  [Bayesian Low-Rank LeArning (Bella): A Practic...
# 19  [Denoising Diffusion Bridge Models Diffusion m...
# 20  [Quantum-Assisted Machine Learning Models for ...
# 21  [HSF: Defending against Jailbreak Attacks with...
# 22  [What is causal about causal models and repres...
# 23  [Solving Partial Differential Equations with R...
# 24  [A Systematic Review of Machine Learning Metho...
# 25  [From LLM Reasoning to Autonomous AI Agents: A...
# 26  [BiCo-Fusion: Bidirectional Complementary LiDA...
# 27  [Deep-Learning Channel Estimation for IRS-Assi...
# 28  [Monitoring digestate application on agricultu...
# 29  [Eliciting Critical Reasoning in Retrieval-Aug...

# %% [markdown]
# ## 5. Evaluation Metric Scores

# %% [markdown]
# Below, we use standard evaluation metrics for topic modeling. We use the OCTIS (Optimizing and Comparing Topic Models is Simple) library to calculate the NPMI topic coherence score and the topic diversity score.
# The coherence score calculation can take a few minutes, even when using multithreading.
#
# The NPMI coherence score of **~0.22** suggests that our topics are reasonably interpretable, meaning the words within each topic tend to be semantically related. Our diversity score of **~0.74** suggests that our model is decently capturing different themes within our data, although an ideal score would be above 80. This is expected, however, since we have limited our topic size to a minimum of 35 representative documents (skipping many smaller topics), and our dataset is supposed to have common themes (topics related to machine learning).
#
# While it is good to have these evaluation metrics, determining the relevance of clustered topics is an inherently subjective process, so it is difficult and impractical to obtain a clear picture of the topic model's quality while only relying on purely quantitative metrics.

# %%
topics_dict = topic_model.get_topics()
topic_words = [
    [w for w, _ in words[:10]]   # Top-10 words per topic
    for tid, words in topics_dict.items()
    if tid != -1                  # Skip the outlier cluster
]

# %%
vectorizer = topic_model.vectorizer_model # The CountVectorizer that c-TF-IDF used
analyzer   = vectorizer.build_analyzer()  # Includes lowercase, n-grams, stop-words

tokenized_docs = [analyzer(d) for d in docs]

# %%
from octis.evaluation_metrics.coherence_metrics import Coherence
from octis.evaluation_metrics.diversity_metrics import TopicDiversity

octis_format = {"topics": topic_words}

coh = Coherence(texts=tokenized_docs, topk=5, processes=4).score(octis_format)
print(f"c_npmi={coh:.3f}")
# Out:
# c_npmi=0.228

# %%
div = TopicDiversity(topk=10).score(octis_format)
print(f"diversity={div:.3f}")
# Out:
# diversity=0.737

# %% [markdown]
# ## 6. Exploring and Visualizing the Results

# %% [markdown]
# ### 6.1 Creating New Topic Labels and Summaries using a Large Language Model

# %% [markdown]
# As seen in the table above, the names of our topics use a simple topic representation model: the topic ID number, followed by the top representative words, separated with underscores.
# We can use a Large Language Model (LLM) to create a more descriptive label. Additionally, we can use it to generate a short summary for each topic.
#
# At the moment, Google offers an experimental version of Gemini Flash 2.0-Lite at only 0.0075 USD per million input tokens and 30 cents per million output tokens. Additionally, it offers 15 requests per minute (RPM) and 1500 free requests per day. It is distinguished for being small, fast, and capable of high quality outputs for non-reasoning tasks. Since the model has a large context window, we do not really need to batch our requests, but our code below processes our topics list in two halves, just in case (some models may have degraded performance when the included context is too large).
#
# We use LiteLLM, a library that supports API calls to many LLM providers using a common interface. With this library, we can swap out our chosen model for a new one in the future without having to rewrite most of the code.
#
# Note: You must set up your own Gemini API key. After creating your key through Google AI Studio, go to the "Add-ons" > "Secrets" > "Add Secret", then create a secret with the name "GEMINI_API_KEY" and paste your unique API token.

# %%
import os, math, json, time
from litellm import completion
from google.colab import userdata
import os

api_key = userdata.get("GEMINI_API_KEY")
os.environ["GEMINI_API_KEY"] = api_key

def prompt_builder(df_chunk):
    # Instructions for the LLM
    system_msg = """You are an ML researcher who names Machine Learning research topic clusters
    generated by BERTopic.
    For each topic you receive, return a JSON object with:
          id      : integer   (the topic ID)
          Label   : ≤ 6 words (concise title)
          Summary : ≤ 25 words (short description of the topic)
        Each topic cluster you receive includes its name and representation (top words and phrases found in the cluster).
        Respond with a JSON list only—no extra text.
    """.strip()

    # Build a small TSV block the model can read
    rows = [
        f"\t{r.Name}\t{r.Representation}"
        for _, r in df_chunk.iterrows()
    ]
    user_msg = (
        "Columns: id, size, placeholder_label, top_keywords\n"
        "```text\n" + "\n".join(rows) + "\n```"
    )

    return [
        {"role": "system", "content": system_msg},
        {"role": "user",   "content": user_msg}
    ]

midpoint = math.ceil(len(topic_info) / 2)
# The API has very generous rate limits, but we are dividing the DataFrame and making two separate calls just as a precaution
first_half  = topic_info.iloc[:midpoint]
second_half = topic_info.iloc[midpoint:]

# Build prompts and call LLM
def call_gemini(df_part):
    messages = prompt_builder(df_part)
    resp = completion(
        model="gemini/gemini-2.0-flash",
        messages=messages,
        response_format={"type": "json_object"},
        temperature=0.3,
        max_tokens=100000,
    )
    raw_json = resp.choices[0].message.content
    return json.loads(raw_json)

results_1 = call_gemini(first_half)
results_2 = call_gemini(second_half)


all_results = results_1 + results_2
all_results.sort(key=lambda d: d["id"])

# %% [markdown]
# The model was instructed to generate its output in structured JSON, which can be easily parsed into a dataframe and merged with the dataframe generated by `get_topic_info()`.

# %%
import json

label_df = pd.DataFrame(all_results)
label_df.rename(columns={"id": "Topic"}, inplace=True)

# Apply to BERTopic
# Merge so we keep original ordering and any extra columns
topic_info = topic_model.get_topic_info()
topic_info = topic_info.merge(label_df, on="Topic", how="left")

# Use the “label” column as custom topic names
custom_labels = topic_info.set_index("Topic")["Label"].to_dict()
topic_model.set_topic_labels(custom_labels)

# Store the summaries for later display
topic_summaries = topic_info.set_index("Topic")["Summary"].to_dict()
print('Topic labels and summaries have been added to the topic model.')
# Out:
# Topic labels and summaries have been added to the topic model.

# %% [markdown]
# ### 6.2 Top Topics Table

# %% [markdown]
# The table below shows the top 30 most frequent topics, including the new summaries and labels, with the outliers topic (Topic -1) at the top. You can change the value of `head(30)` to see more or less of the top topics. You can also change `head(30)` to `tail(30)` to see the bottom 30 topics as well.

# %%
topic_info[["Topic", "Count", "Name", "Label", "Summary"]].head(30)
# Out:
#     Topic  Count                                               Name  \
# 0      -1   3721                      -1_models_data_model_learning
# 1       0    774                    0_learning_neural_networks_data
# 2       1    342             1_language_llms_models_language models
# 3       2    319          2_federated_fl_federated learning_clients
# 4       3    314   3_reinforcement_reinforcement learning_rl_policy
# 5       4    294            4_traffic_driving_autonomous_trajectory
# 6       5    253                    5_segmentation_images_mri_image
# 7       6    244                 6_ai_human_intelligence_ai systems
# 8       7    242                   7_visual_multimodal_image_vision
# 9       8    226               8_robot_manipulation_robots_learning
# 10      9    219                           9_graph_node_graphs_gnns
# 11     10    216              10_code_software_llms_code generation
# 12     11    183             11_series_time series_time_forecasting
# 13     12    164                12_reasoning_llms_mathematical_math
# 14     13    151         13_adversarial_attacks_robustness_backdoor
# 15     14    151            14_recommendation_user_recommender_item
# 16     15    144                        15_speech_audio_speaker_asr
# 17     16    141                    16_regret_bandit_online_bandits
# 18     17    141        17_bayesian_uncertainty_inference_posterior
# 19     18    139     18_diffusion_diffusion models_models_denoising
# 20     19    138      19_quantum_classical_quantum machine_learning
# 21     20    137                      20_attacks_llms_attack_safety
# 22     21    135     21_causal_treatment_variables_causal discovery
# 23     22    134                       22_neural_pdes_equations_pde
# 24     23    130                          23_eeg_brain_fmri_signals
# 25     24    130                       24_agents_agent_language_llm
# 26     25    129  25_object_segmentation_object detection_detection
# 27     26    121                   26_channel_network_wireless_edge
# 28     27    120                   27_crop_detection_images_species
# 29     28    117                28_retrieval_rag_question_knowledge
#
#                                Label  \
# 0           General Machine Learning
# 1        Neural Network Optimization
# 2       Large Language Models (LLMs)
# 3     Federated Learning for Privacy
# 4    Reinforcement Learning & Policy
# 5    Autonomous Driving & Trajectory
# 6         Medical Image Segmentation
# 7            AI & Human Intelligence
# 8             Visual-Language Models
# 9   Robotics & Manipulation Learning
# 10             Graph Neural Networks
# 11         Code Generation with LLMs
# 12           Time Series Forecasting
# 13  Mathematical Reasoning with LLMs
# 14  Adversarial Attacks & Robustness
# 15            Recommendation Systems
# 16         Speech & Audio Processing
# 17        Bandit Algorithms & Regret
# 18  Bayesian Uncertainty & Inference
# 19      Diffusion Models & Denoising
# 20          Quantum Machine Learning
# 21              LLM Security Attacks
# 22      Causal Inference & Discovery
# 23           Neural PDEs & Equations
# 24       EEG & Brain Signal Analysis
# 25                        LLM Agents
# 26   Object Detection & Segmentation
# 27    Wireless Network Communication
# 28          Crop & Species Detection
# 29    Retrieval Augmented Generation
#
#                                               Summary
# 0   General ML topics including models, data, lear...
# 1   Learning, neural networks, data, gradient desc...
# 2   Language models, LLMs, large language models, ...
# 3   Federated learning (FL), privacy, clients, dis...
# 4   Reinforcement learning (RL), policy learning, ...
# 5   Traffic, autonomous driving, trajectory predic...
# 6   Segmentation of medical images (MRI), cancer i...
# 7   Artificial intelligence (AI), human intelligen...
# 8   Visual, multimodal learning, image processing,...
# 9   Robot manipulation, robotic learning, task aut...
# 10  Graph neural networks (GNNs), node classificat...
# 11  Code generation, software development, LLMs, p...
# 12  Time series analysis, forecasting, temporal da...
# 13  Reasoning, LLMs, mathematical problem-solving,...
# 14  Adversarial attacks, robustness, backdoor atta...
# 15  Recommendation systems, user modeling, recomme...
# 16  Speech processing, audio analysis, speaker rec...
# 17  Regret minimization, bandit algorithms, online...
# 18  Bayesian methods, uncertainty quantification, ...
# 19  Diffusion models, denoising, image generation,...
# 20  Quantum computing, classical algorithms, quant...
# 21  Attacks on LLMs, safety, jailbreaking, adversa...
# 22  Causal inference, treatment effects, variable ...
# 23  Neural networks for partial differential equat...
# 24  EEG, brain signals, fMRI, signal classificatio...
# 25  AI Agents, language models (LLMs), game playin...
# 26  Object detection, segmentation, 3D vision, LiD...
# 27  Channel modeling, network optimization, wirele...
# 28  Crop detection, image analysis, species identi...
# 29  Retrieval-augmented generation (RAG), question...

# %% [markdown]
# ### 6.3 Intertopic Distance Map

# %% [markdown]
# Our first visualization shows the relationships between topics in a 2D space. Topics that are closer together are semantically more similar. Since we set the labels generated by the LLM as our custom topic labels, they can now be used in the visualizations.
#
#
# The map allows for interactive exploration. Upon hovering over the circles, the topic names and sizes are shown. Any area can be selected to zoom in for closer inspection. The size of each circle corresponds to the topic's prevalence in the dataset, making it easy to identify dominant themes.
#
# This visualization provides a clear and intuitive overview of topic relationships, and allows us to see which topics have enough overlap to be merged if we want to trim down our number of topics even further. To see the topic labels, sizes and IDs, simply hover over each circle with the mouse. The slider can be used to highlight a specific topic.

# %%
fig = topic_model.visualize_topics(custom_labels=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d9e5f184-ec4b-4ae6-8cab-5a1b2b4d86fa" class="plotly-graph-div" style="height:650px; width:650px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9e5f184-ec4b-4ae6-8cab-5a1b2b4d86fa")) {                    Plotly.newPlot(                        "d9e5f184-ec4b-4ae6-8cab-5a1b2b4d86fa",                        [{"customdata":[[0,"Neural Network Optimization",774],[1,"Large Language Models (LLMs)",342],[2,"Federated Learning for Privacy",319],[3,"Reinforcement Learning & Policy",314],[4,"Autonomous Driving & Trajectory",294],[5,"Medical Image Segmentation",253],[6,"AI & Human Intelligence",244],[7,"Visual-Language Models",242],[8,"Robotics & Manipulation Learning",226],[9,"Graph Neural Networks",219],[10,"Code Generation with LLMs",216],[11,"Time Series Forecasting",183],[12,"Mathematical Reasoning with LLMs",164],[13,"Adversarial Attacks & Robustness",151],[14,"Recommendation Systems",151],[15,"Speech & Audio Processing",144],[16,"Bandit Algorithms & Regret",141],[17,"Bayesian Uncertainty & Inference",141],[18,"Diffusion Models & Denoising",139],[19,"Quantum Machine Learning",138],[20,"LLM Security Attacks",137],[21,"Causal Inference & Discovery",135],[22,"Neural PDEs & Equations",134],[23,"EEG & Brain Signal Analysis",130],[24,"LLM Agents",130],[25,"Object Detection & Segmentation",129],[26,"Wireless Network Communication",121],[27,"Crop & Species Detection",120],[28,"Retrieval Augmented Generation",117],[29,"News Bias & Social Issues",115],[30,"Image & Text Generation",114],[31,"Molecular & Drug Discovery",105],[32,"Privacy and Differential Privacy",104],[33,"LLMs in Healthcare and Medicine",96],[34,"Explainable AI (XAI) Methods",93],[35,"Emotion Recognition and Mental Health",90],[36,"Weather and Climate Forecasting",90],[37,"Financial Market Prediction and Trading",87],[38,"Continual Learning and Catastrophic Forgetting",87],[39,"AI in Education and Student Learning",86],[40,"Fairness and Bias in Machine Learning",80],[41,"Hardware Accelerators for Deep Learning",79],[42,"Materials Science and Property Prediction",78],[43,"3D Scene Reconstruction and Rendering",74],[44,"Preference Learning and Human Feedback",69],[45,"Spiking Neural Networks (SNNs)",69],[46,"Optimization Problems and Search Algorithms",69],[47,"Clustering Algorithms and Data Structure",68],[48,"Anomaly Detection in Time Series Data",65],[49,"Video Understanding and Temporal Analysis",64],[50,"Fault Diagnosis in Manufacturing Processes",57],[51,"Attention Mechanisms in Transformers",54],[52,"Medical Report Generation in Radiology",54],[53,"Clinical Prediction and Disease Diagnosis",50],[54,"Protein Sequence and Structure Prediction",50],[55,"Ontology and Knowledge Graph Applications",49],[56,"Music Generation and Symbolic Music",48],[57,"Human Activity Recognition Using Sensors",45],[58,"Energy Load Forecasting and Power Consumption",43],[59,"Hallucination Detection in Language Models",41],[60,"Dynamical Systems and Data-Driven Dynamics",40],[61,"Logic Programming and Argumentation",39],[62,"Neutrino Physics and Particle Detection",39],[63,"Intrusion Detection in IoT Security",36],[64,"Energy Management with Reinforcement Learning",31]],"hovertemplate":"\u003cb\u003eTopic %{customdata[0]}\u003c\u002fb\u003e\u003cbr\u003e%{customdata[1]}\u003cbr\u003eSize: %{customdata[2]}","legendgroup":"","marker":{"color":"#B0BEC5","size":[774,342,319,314,294,253,244,242,226,219,216,183,164,151,151,144,141,141,139,138,137,135,134,130,130,129,121,120,117,115,114,105,104,96,93,90,90,87,87,86,80,79,78,74,69,69,69,68,65,64,57,54,54,50,50,49,48,45,43,41,40,39,39,36,31],"sizemode":"area","sizeref":0.48375,"symbol":"circle","line":{"color":"DarkSlateGrey","width":2}},"mode":"markers","name":"","orientation":"v","showlegend":false," ...

# %% [markdown]
# ### 6.4 Topic Word Scores Chart

# %% [markdown]
# This bar chart visualization highlights the top words associated with each topic identified by the BERTopic model. The topics are represented by their most representative terms, ranked by relevance scores. The length of the bars corresponds to the importance of each word in defining the topic. Note how the Reinforcement Learning topic is not just represented by 'reinforcement' and 'learning,' but also by related concepts such as 'reward' (the feedback signal that the algorithm seeks to maximize over time) and 'policy' (the strategy or mapping from states to actions that the algorithm learns).
# This demonstrates how the BERTopic model's underlying embeddings effectively capture the semantic relationships between terms and concepts.

# %%
fig = topic_model.visualize_barchart(custom_labels=True, height=300, width=385)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3c1ca0cc-f33c-40be-8ec6-030c1ec2eaaf" class="plotly-graph-div" style="height:600px; width:1540px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3c1ca0cc-f33c-40be-8ec6-030c1ec2eaaf")) {                    Plotly.newPlot(                        "3c1ca0cc-f33c-40be-8ec6-030c1ec2eaaf",                        [{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.007108877900098543,0.007625062976084071,0.008010398448832952,0.00849709669219934,0.008788885685222932],"y":["gradient  ","data  ","networks  ","neural  ","learning  "],"type":"bar","xaxis":"x","yaxis":"y"},{"marker":{"color":"#0072B2"},"orientation":"h","x":[0.012605973582751426,0.013888394914604849,0.014599991258152617,0.015097829601205138,0.019093725762514367],"y":["large  ","language models  ","models  ","llms  ","language  "],"type":"bar","xaxis":"x2","yaxis":"y2"},{"marker":{"color":"#CC79A7"},"orientation":"h","x":[0.019625590643460016,0.020978561723523477,0.03156943147253814,0.033074399818580354,0.04179024088179211],"y":["privacy  ","clients  ","federated learning  ","fl  ","federated  "],"type":"bar","xaxis":"x3","yaxis":"y3"},{"marker":{"color":"#E69F00"},"orientation":"h","x":[0.01697958025382122,0.022656111252266267,0.023049943473845872,0.023540691405412595,0.023596954074701686],"y":["learning  ","policy  ","rl  ","reinforcement learning  ","reinforcement  "],"type":"bar","xaxis":"x4","yaxis":"y4"},{"marker":{"color":"#56B4E9"},"orientation":"h","x":[0.012188435370158584,0.012748589133410619,0.01682650181886581,0.022580174472691478,0.02282175932241115],"y":["vehicle  ","trajectory  ","autonomous  ","driving  ","traffic  "],"type":"bar","xaxis":"x5","yaxis":"y5"},{"marker":{"color":"#009E73"},"orientation":"h","x":[0.0125446017396586,0.012847016861379039,0.013555325107390132,0.014011339382350059,0.02188131087442964],"y":["medical  ","image  ","mri  ","images  ","segmentation  "],"type":"bar","xaxis":"x6","yaxis":"y6"},{"marker":{"color":"#F0E442"},"orientation":"h","x":[0.010335582894462039,0.010420550914262998,0.010928857945559622,0.019437809389607954,0.05149102397485432],"y":["systems  ","ai systems  ","intelligence  ","human  ","ai  "],"type":"bar","xaxis":"x7","yaxis":"y7"},{"marker":{"color":"#D55E00"},"orientation":"h","x":[0.015058946652033802,0.015197336923342773,0.01593515842602165,0.016324463898088948,0.023479623762517783],"y":["language  ","vision  ","image  ","multimodal  ","visual  "],"type":"bar","xaxis":"x8","yaxis":"y8"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"white","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"#C8D4E3","linecolor":"#C8D4E3","minorgridcolor":"#C8D4E3","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111 ...

# %% [markdown]
# ### 6.5 Topic Similarity Heatmap

# %% [markdown]
# The similarity matrix heatmap offers a good way to inspect the relationships between pairs of topics. Each row and column corresponds to a particular topic, and the color of each cell reflects the degree of semantic similarity between those two topics. Darker cells along the diagonal indicate higher self-similarity (a topic compared to itself), while off-diagonal cells reveal how related (or unrelated) different topics are.
#
# From the heatmap, you can see which topics tend to cluster together. Topics that share conceptual ground, such as “Bandit Algorithms” and “Reinforcement Learning Policies”, appear in regions of higher similarity, suggesting that the language used to describe them overlaps significantly. Conversely, less closely related topics have lower similarity scores, appearing in lighter-colored cells. Note that the results below might differ from the examples described, due to the stochastic nature of the topic model and the LLM outputs.

# %%
fig = topic_model.visualize_heatmap(custom_labels=True, top_n_topics=25)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1291d915-e07c-4f7c-ad0d-4685573d604f" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1291d915-e07c-4f7c-ad0d-4685573d604f")) {                    Plotly.newPlot(                        "1291d915-e07c-4f7c-ad0d-4685573d604f",                        [{"coloraxis":"coloraxis","name":"0","x":["Neural Network Optimization","Large Language Models (LLMs)","Federated Learning for Privacy","Reinforcement Learning & Policy","Autonomous Driving & Trajectory","Medical Image Segmentation","AI & Human Intelligence","Visual-Language Models","Robotics & Manipulation Learning","Graph Neural Networks","Code Generation with LLMs","Time Series Forecasting","Mathematical Reasoning with LLMs","Adversarial Attacks & Robustness","Recommendation Systems","Speech & Audio Processing","Bandit Algorithms & Regret","Bayesian Uncertainty & Inference","Diffusion Models & Denoising","Quantum Machine Learning","LLM Security Attacks","Causal Inference & Discovery","Neural PDEs & Equations","EEG & Brain Signal Analysis","LLM Agents"],"y":["Neural Network Optimization","Large Language Models (LLMs)","Federated Learning for Privacy","Reinforcement Learning & Policy","Autonomous Driving & Trajectory","Medical Image Segmentation","AI & Human Intelligence","Visual-Language Models","Robotics & Manipulation Learning","Graph Neural Networks","Code Generation with LLMs","Time Series Forecasting","Mathematical Reasoning with LLMs","Adversarial Attacks & Robustness","Recommendation Systems","Speech & Audio Processing","Bandit Algorithms & Regret","Bayesian Uncertainty & Inference","Diffusion Models & Denoising","Quantum Machine Learning","LLM Security Attacks","Causal Inference & Discovery","Neural PDEs & Equations","EEG & Brain Signal Analysis","LLM Agents"],"z":[[1.0000001,0.90269816,0.9094571,0.8949088,0.91009253,0.92462134,0.8463776,0.8954467,0.88691545,0.9129782,0.8663737,0.9246872,0.87434,0.9175566,0.8963845,0.90439516,0.9074896,0.9544218,0.9241354,0.88979214,0.864322,0.90849465,0.92068434,0.91378397,0.84476954],[0.90269816,1.0000002,0.85150653,0.8367511,0.85566866,0.84288156,0.83682364,0.9358585,0.8428547,0.8582672,0.91052294,0.8744759,0.9358278,0.84314394,0.8779649,0.9235759,0.8193459,0.8661594,0.8451889,0.81651497,0.92601043,0.83481556,0.8325592,0.8509704,0.90072757],[0.9094571,0.85150653,0.99999994,0.85081416,0.8646899,0.8461954,0.8460318,0.83486116,0.82653195,0.86363477,0.8369307,0.86299115,0.8396514,0.86744195,0.8685772,0.82934153,0.8695743,0.85922974,0.83012193,0.82383776,0.8566614,0.854944,0.82930803,0.83273435,0.83974004],[0.8949088,0.8367511,0.85081416,1.0000001,0.9034935,0.8064433,0.88168913,0.8253714,0.9412519,0.82743615,0.8324757,0.85093355,0.87,0.83391404,0.8501499,0.8173733,0.9371597,0.90183675,0.8481537,0.8499012,0.8289258,0.8775257,0.8418005,0.8301081,0.9215909],[0.91009253,0.85566866,0.8646899,0.9034935,0.99999994,0.86842895,0.8760526,0.8805409,0.9127062,0.8643574,0.85240656,0.9009922,0.8607344,0.85021794,0.8636739,0.8569744,0.8703329,0.8942941,0.8661805,0.83144253,0.8378235,0.87226844,0.8635042,0.8726285,0.87913007],[0.92462134,0.84288156,0.8461954,0.8064433,0.86842895,1.0000002,0.809967,0.8900354,0.8410185,0.8636383,0.8090606,0.8576515,0.81899697,0.8619315,0.8197797,0.8593262,0.8037902,0.87955755,0.899417,0.8216147,0.8001339,0.85423404,0.8712325,0.90764785,0.78645974],[0.8463776,0.83682364,0.8460318,0.88168913,0.8760526,0.809967,0.9999995,0.83589077,0.8801124,0.79677874,0.8783576,0.8206343,0.880646,0.82066023,0.8425261,0.81372696,0.85531896,0.8288822,0.79104793,0.82294786,0.8672603,0.86037135,0.79827243,0.8430952,0.9331985],[0.8954467,0.9358585,0.83486116,0.8253714,0.8805409,0.8900354,0.83589077,1.0000002,0.8739853,0.8630583,0.86981314,0 ...

# %% [markdown]
# ## 7. Document-Level Visualizations

# %% [markdown]
# ### 7.1 Visualize Documents with Hoverable Titles

# %% [markdown]
# The following visualization is a scatter plot where each point represents a document. This scatter plot visualizes the distribution of documents and their assigned topics in a two-dimensional space. Each point represents a document, and points are colored according to their topic. Labels indicate the general area of the plot where a particular topic is most prominent, showing how the BERTopic model clusters semantically similar documents together.
#
# The documents are colored by their assigned topic. Hovering over a point shows the document's title.
#
# The clustering and separation of points indicate the effectiveness of the topic modeling process, with clear groupings suggesting coherent topic definitions.

# %%
fig = topic_model.visualize_documents(df["title"],
                           title="Documents and Topics",
                           embeddings=embeddings,
                           custom_labels=True,
                           hide_annotations=True,
                           topics=topics)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="dc7e2567-e0e5-4890-abcc-61dad63602a8" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dc7e2567-e0e5-4890-abcc-61dad63602a8")) {                    Plotly.newPlot(                        "dc7e2567-e0e5-4890-abcc-61dad63602a8",                        [{"hoverinfo":"text","hovertext":["HALO: Hardware-aware quantization with low critical-path-delay weights for LLM acceleration","Enabling Autonomic Microservice Management through Self-Learning Agents","Diversity is Strength: Mastering Football Full Game with Interactive Reinforcement Learning of Multiple AIs","Embodied Red Teaming for Auditing Robotic Foundation Models","Enhancing Efficiency and Privacy in Memory-Based Malware Classification through Feature Selection","A Novel Approach to Image Steganography Using Generative Adversarial Networks","Effective resistance in metric spaces","Analysis of the vulnerability of machine learning regression models to adversarial attacks using data from 5G wireless networks","DailyMAE: Towards Pretraining Masked Autoencoders in One Day","Love in Action: Gamifying Public Video Cameras for Fostering Social Relationships in Real World","HVI: A New Color Space for Low-light Image Enhancement","NNQS-Transformer: an Efficient and Scalable Neural Network Quantum States Approach for Ab initio Quantum Chemistry","Comet: Fine-grained Computation-communication Overlapping for Mixture-of-Experts","Dataset Condensation Driven Machine Unlearning","VA3: Virtually Assured Amplification Attack on Probabilistic Copyright Protection for Text-to-Image Generative Models","Revolutionizing Personalized Cancer Vaccines with NEO: Novel Epitope Optimization Using an Aggregated Feed Forward and Recurrent Neural Network with LSTM Architecture","Cartesian Genetic Programming Approach for Designing Convolutional Neural Networks","Combining physics-based and data-driven models: advancing the frontiers of research with Scientific Machine Learning","ToolNet: Connecting Large Language Models with Massive Tools via Tool Graph","Correcting for heterogeneity in real-time epidemiological indicators","RAGDiffusion: Faithful Cloth Generation via External Knowledge Assimilation","AdANNS: A Framework for Adaptive Semantic Search","Multitask learning for improved scour detection: A dynamic wave tank study","In Search of Lost Online Test-time Adaptation: A Survey","Large-Scale Application of Fault Injection into PyTorch Models -- an Extension to PyTorchFI for Validation Efficiency","Fantastic Multi-Task Gradient Updates and How to Find Them In a Cone","Hypothesis-free discovery from epidemiological data by automatic detection and local inference for tree-based nonlinearities and interactions","The Power of MEME: Adversarial Malware Creation with Model-Based Reinforcement Learning","Preface: A Data-driven Volumetric Prior for Few-shot Ultra High-resolution Face Synthesis","SANGRIA: Surgical Video Scene Graph Optimization for Surgical Workflow Prediction","Modular Boundaries in Recurrent Neural Networks","Independent Component Alignment for Multi-Task Learning","CSTalk: Correlation Supervised Speech-driven 3D Emotional Facial Animation Generation","Neural Network Verification with PyRAT","Disentangled Representations for Causal Cognition","Multi-Objective Quality-Diversity in Unstructured and Unbounded Spaces","RAGFormer: Learning Semantic Attributes and Topological Structure for Fraud Detection","Positional Information Matters for Invariant In-Context Learning: A Case Study of Simple Function Classes","Attractor reconstruction with reservoir computers: The effect of the reservoir's conditional Lyapunov exponents on faithful attractor reconstruction","What are human values, and  ...

# %% [markdown]
# ### 7.2 Documents with Labeled Topics

# %% [markdown]
# This version of the visualization shows the document clusters with their respective topic labels. In order to make space for the labels, only the top 55 document clusters are used for the `topics` parameter.

# %%
top_topics = topics[:55]
fig = topic_model.visualize_documents(docs,
                           title="Documents and Topics",
                           embeddings=embeddings,
                           hide_document_hover=True,
                           custom_labels=True,
                           topics=top_topics)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b7d12e32-eeef-4713-af10-6c93ba9be31a" class="plotly-graph-div" style="height:750px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7d12e32-eeef-4713-af10-6c93ba9be31a")) {                    Plotly.newPlot(                        "b7d12e32-eeef-4713-af10-6c93ba9be31a",                        [{"hoverinfo":"text","marker":{"color":"#CFD8DC","opacity":0.5,"size":5},"mode":"markers+text","name":"other","showlegend":false,"x":[4.7402205,4.6688423,4.4638224,5.0806603,5.2178626,4.9290657,5.249262,4.607149,4.412267,5.556754,5.1315413,5.4418044,3.9643457,5.4648,5.285054,5.56176,5.624406,4.3214083,6.509723,5.0836997,5.095101,5.0938754,4.8219767,5.1492977,5.4611797,5.628706,5.182953,5.1910744,5.2646337,5.131007,5.3032165,5.139606,5.65899,5.6208196,5.6542034,5.3030243,5.317966,5.617236,5.084298,5.9557605,4.8601913,4.173864,4.4571843,4.8660603,4.694214,4.631581,4.390142,4.9178505,5.208921,5.1657124,5.1513195,4.6354656,4.5345407,5.3697033,4.8233128,4.6827784,4.695779,5.5131316,4.578631,5.2615643,4.7300434,5.261699,5.2354736,5.06577,4.4396987,5.3228755,5.690406,4.62652,5.8305435,5.2243176,5.0585256,4.751653,5.6297493,5.572892,5.5675807,4.754534,5.431961,4.7590203,5.6519666,5.424367,4.248264,5.3649907,5.657778,4.426396,5.7703295,5.35524,4.356594,5.4085093,5.173336,5.1714535,5.004639,4.507778,4.108451,5.7459354,5.360045,5.276141,5.394602,5.4446497,4.5621686,5.1847,4.7416244,4.5896163,4.8640995,4.4081807,5.73645,4.357714,4.593988,5.2676697,5.1738915,4.69371,5.544121,5.1605544,5.584322,4.429071,4.5260158,5.2812457,4.8987885,4.680388,5.278261,4.485232,4.8207235,5.090436,4.7727227,5.4274864,4.944507,5.504146,5.466557,5.397348,4.814826,5.6743307,4.6197896,4.801001,5.8941083,4.5051775,5.153623,4.8382416,5.4303546,4.407071,4.911317,4.9613795,5.458185,4.914914,4.602735,5.1328597,4.5722804,5.175567,5.3640203,5.685121,4.8471622,5.542923,5.096049,4.5184693,4.373522,5.025052,5.7030764,5.4509964,4.9271407,4.534012,5.7178044,5.1086497,3.999468,4.740779,4.5168614,4.0540547,5.5983405,4.0680757,5.445254,5.0566983,5.391046,4.0075455,5.3958573,4.3583684,5.640831,5.307373,4.9372253,4.667631,5.393632,5.69235,5.1960473,4.572915,5.483721,5.361853,5.3248086,4.9580207,5.606421,4.8883185,5.08387,4.657823,5.6253004,5.3004313,5.426761,5.3969913,5.1921225,4.9289207,4.912389,4.505012,5.2173743,4.585969,4.377182,4.5758305,5.474951,5.259585,4.8977466,4.5336313,5.35648,5.67398,5.704435,4.4980607,4.044102,5.716069,5.805067,5.8267593,4.367635,4.2626905,4.5879073,5.8551183,5.1608,4.5687013,4.971707,4.506718,4.5187397,5.3451,4.2066193,5.1420555,5.8778934,5.067553,4.906276,4.7733803,4.8459444,5.509374,4.5309863,5.6083727,4.856321,4.3923507,4.9166903,5.6695094,5.4692864,4.7044587,5.6711426,7.161571,5.4093523,4.529364,4.3096757,5.1493964,5.5329113,4.9853296,5.497725,5.6619196,4.060362,4.882096,5.37718,4.445173,5.3789687,5.176728,4.5331516,5.713813,5.121736,5.472923,5.1705513,5.7085915,5.52611,4.8586617,5.174865,5.4746246,4.6574626,8.621173,5.5585437,5.70295,4.446115,5.7504497,4.316435,4.6167936,4.245841,5.077804,4.648693,4.5782466,5.6501946,4.741876,4.628538,5.2129617,5.3946314,5.562624,4.873878,4.721062,5.436932,4.550621,5.0174704,3.9712424,5.7954884,4.242139,4.7546554,5.4466743,5.3038664,1.928809,0.34952977,0.5597836,0.38462844,0.59785014,0.36241823,0.4546322,0.39935824,0.46441153,0.43351844,0.49623626,0.3726257,0.41199434,0.5772733,0.62457234,0.41214073,0.47319424,0.4316896,0.68564814,0.5324573,0.31178966,0.395456,0.45694673,0.33104202,0.66659373,0.32968783,0.39904696,0.364252,0.45167455,0.319634,0.33927587,0.52316463,0.40035027,0.47286144,0.45803133,0.39867792,0.44723397,0.4089924,0.41531584,0.3021777,0.37216687,0.5442288,4.813749,0.37584254,0.29515573,0.42416263,0.14152652,0.35165343,0.43861872,0.5189483,0.561 ...

# %% [markdown]
# ## 8. Topic Search

# %% [markdown]
# Below, we put our topic modeling to use with a search engine for our data, which allows you to filter by topic. The engine uses a simple cosine similarity algorithm and leverages the same embedding model that was used for the topic model.
#
# * Enter you search query and click the search button to search accross all topics.
# * Click on a topic from the list to choose a filter.
# * Click the clear button to remove your input text and your filtered topic.
#
# Try the following search queries with no filter selected: "rag", "SAM", "cluster", and "diffusion".

# %%
import numpy as np
import ipywidgets as widgets
from IPython.display import display, HTML, clear_output
from sklearn.metrics.pairwise import cosine_similarity

def search_papers(
    query,
    topic_model,
    df,
    embeddings,
    embedder,
    top_k=15,
    topic_filter=None):
    # Encode the query
    query_emb = embedder.encode([query], show_progress_bar=False)

    # 2. Get all document topics from the model
    doc_topics = np.array(topic_model.topics_)

    # 3. Apply the topic filter before calculating similarity
    search_indices = np.arange(len(embeddings))
    search_embeddings = embeddings

    if topic_filter:
        mask = np.isin(doc_topics, topic_filter)
        search_indices = np.where(mask)[0]

        if len(search_indices) == 0:
            return []

        search_embeddings = embeddings[search_indices]

    # 4. Calculate cosine similarity against the (potentially filtered) embeddings
    similarities = cosine_similarity(query_emb, search_embeddings)[0]

    # 5. Get the top-k indices from the filtered results
    num_results = min(top_k, len(similarities))
    if num_results == 0:
        return []

    top_filtered_indices = np.argpartition(similarities, -num_results)[-num_results:]
    top_filtered_indices = top_filtered_indices[np.argsort(similarities[top_filtered_indices])[::-1]]

    # 6. Build the results list
    results = []
    for idx in top_filtered_indices:
        original_idx = search_indices[idx]
        topic_id = doc_topics[original_idx]
        try:
            if topic_id == "-1":
                topic_label = "Outlier Topics"
            else:
                topic_label = topic_info.loc[topic_info["Topic"] == topic_id, "Label"].iloc[0]
                topic_summary = topic_info.loc[topic_info["Topic"] == topic_id, "Summary"].iloc[0]
        except IndexError:
            topic_label = f"Topic {topic_id}"
            topic_summary = ""

        results.append(
            {
                "title": df.at[original_idx, "title"],
                "summary": df.at[original_idx, "summary"],
                "topic": topic_label,
                "topic_summary": topic_summary,
                "topic_id": int(topic_id),
                "similarity": float(similarities[idx]),
            }
        )
    return results


def create_search_interface(
    topic_model,
    df,
    embeddings,
    embedder,
    topic_info):
    """
    Creates and displays a search interface in a Jupyter environment.
    """

    # Widgets
    search_box = widgets.Text(
        placeholder="Enter search query…",
        description="Search:",
        layout=widgets.Layout(width="50%"),
    )

    topic_options = [
        (row["Name"], int(row["Topic"]))
        for _, row in topic_info[topic_info["Topic"] != -1].iterrows()
    ]

    topic_dropdown = widgets.SelectMultiple(
        options=topic_options,
        description="Filter topics:",
        layout=widgets.Layout(width="50%", height="200px"),
    )

    results_out = widgets.Output()

    def run_search(_):
        with results_out:
            clear_output()
            if not search_box.value.strip():
                display(HTML("<em>Please enter a search query.</em>"))
                return

            topic_filter = list(topic_dropdown.value) or None

            hits = search_papers(
                search_box.value,
                topic_model,
                df,
                embeddings,
                embedder,
                top_k=15,
                topic_filter=topic_filter,
            )

            if not hits:
                display(HTML("<em>No results found.</em>"))
                return

            for i, hit in enumerate(hits, 1):
                html = f"""
                <div style="margin:12px 0; padding:12px; border:1px solid #e0e0e0; border-radius: 8px;">
                    <h3 style="margin-top:0;">{i}. {hit['title']}</h3>
                    <p><b>Topic:</b> {hit['topic']} (ID: {hit['topic_id']})</p>
                    <p><b>Similarity:</b> {hit['similarity']:.3f}</p>
                    <p><b>Summary:</b> {hit['summary'][:500]}…</p>
                    <p><b>Topic Summary:</b> {hit['topic_summary'][:500]}.</p>

                </div>"""
                display(HTML(html))

    def clear_form(_):
        search_box.value = ""
        topic_dropdown.value = ()
        with results_out:
            clear_output()

    # Assemble UI
    search_btn = widgets.Button(description="Search", button_style='primary')
    clear_btn = widgets.Button(description="Clear")
    search_btn.on_click(run_search)
    clear_btn.on_click(clear_form)

    ui = widgets.VBox(
        [
            search_box,
            topic_dropdown,
            widgets.HBox([search_btn, clear_btn]),
            results_out,
        ]
    )
    display(ui)

create_search_interface(topic_model, df, embeddings, embedding_model, topic_info)
# Out:
# VBox(children=(Text(value='', description='Search:', layout=Layout(width='50%'), placeholder='Enter search que…
